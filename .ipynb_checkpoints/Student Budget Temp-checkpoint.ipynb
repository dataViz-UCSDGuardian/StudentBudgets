# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bokeh.charts as bk
import plotly.plotly as py

# %%
#only 2016 data
df = pd.read_table("StudentBudget2016.tsv", delimiter = '\t')
df = df[df["Type"] == "All Students"]
del df["Type"]
del df["Systemwide"]

df = df.set_index("Item")
df = df.transpose()
del df["Total"]
df
# Out:
# Item           Books&Supplies  Living  Personal  Transportation  Healthcare  \
# Berkeley                 1262   11966      1770             720        2612
# Davis                    1601    9534      1904            1267        2292
# Irvine                   1766    9677      1984            1440        1675
# Los Angeles              1636   12287      1794             921        2150
# Merced                   1444   10552      1877            1134        2271
# Riverside                1716   10034      2008            1405        1629
# San Diego                1541   10826      1849            1259        2011
# Santa Barbara            1431   11703      1842             915        3150
# Santa Cruz               1470   12715      1768             934        2875
#
# Item           Systemwide fees  Campus fees
# Berkeley                 12294         1214
# Davis                    12294         1752
# Irvine                   12294         1066
# Los Angeles              12294          626
# Merced                   12294          968
# Riverside                12294         1287
# San Diego                12294         1351
# Santa Barbara            12294         1778
# Santa Cruz               12294         1244

# %%
#blank for later initialization
data = pd.DataFrame()
dataOn = pd.DataFrame()
dataOf = pd.DataFrame()
dataCo = pd.DataFrame()
st = ""

#retrieval file names and string names
source = pd.read_csv("filename_year.csv")

#ignore first element of tuple (df indexes)
for (a,file, yr) in source.itertuples():
    df = pd.read_table(file, delimiter = '\t')
    #del df["Berkeley"]
    #del df["Davis"]
    #del df["Irvine"]
    #del df["Los Angeles"]
    #del df["Merced"]
    #del df["Riverside"]
    #del df["Santa Barbara"]
    #del df["Santa Cruz"]
    #del df["Systemwide"]
    
    #set the index labels
    df = df.set_index("Item")
    del df.T["Total"]
    
    df.columns = [str(col) + str(yr) for col in df.columns]
    
    #set if first dataset, else concatenate dfs
    if len(data) == 0:
        dataOn = df[df["Type"+str(yr)] == "On-Campus"]
        dataOf = df[df["Type"+str(yr)] == "Off-Campus"]
        dataCo = df[df["Type"+str(yr)] == "Commuter"]
        data = df[df["Type"+str(yr)] == "All Students"]    
    else:
        data = pd.concat([data,df[df["Type"+str(yr)] == "All Students"]], axis=1)
        dataOn = pd.concat([dataOn,df[df["Type"+str(yr)] == "On-Campus"]], axis=1)
        dataOf = pd.concat([dataOf,df[df["Type"+str(yr)] == "Off-Campus"]], axis=1)
        dataCo = pd.concat([dataCo,df[df["Type"+str(yr)] == "Commuter"]], axis=1)
    
    #sorted by Type, column unnecessary
    del data["Type"+str(yr)]
    del dataOn["Type"+str(yr)]
    del dataOf["Type"+str(yr)]
    del dataCo["Type"+str(yr)]
    
    '''
    #set if first dataset, else concatenate dfs
    if len(data) == 0:
        dataOn = df[df["Type"] == "On-Campus"]
        dataOf = df[df["Type"] == "Off-Campus"]
        dataCo = df[df["Type"] == "Commuter"]
        data = df[df["Type"] == "All Students"]    
    else:
        data = pd.concat([data,df[df["Type"] == "All Students"]], axis=1)
        dataOn = pd.concat([dataOn,df[df["Type"] == "On-Campus"]], axis=1)
        dataOf = pd.concat([dataOf,df[df["Type"] == "Off-Campus"]], axis=1)
        dataCo = pd.concat([dataCo,df[df["Type"] == "Commuter"]], axis=1)
    
    #alldata = [dataOn, dataOf, dataCo, data]
    #for dfx in alldata:
    #    dfx.columns = [str(col) + str(yr) for col in dfx.columns]
    
    del data["Type"]
    del dataOn["Type"]
    del dataOf["Type"]
    del dataCo["Type"]
    '''
    
#data = data[data["Type"] == "All Students"]
#data = data.reset_index()
#data = data[data["Item"] == "Living"]
#data = data[data["Item"] != "Transportation"]
#data = data[data["Item"] != "Healthcare"]
#data = data[data["Item"] != "Personal"]
#data = data[data["Item"] == "Systemwide fees"]
#data = data.set_index("Item")
dataOf.T
# Out:
# Item              Books&Supplies Living Personal Transportation Healthcare  \
# Berkeley2006                1326   9122     1606           1160       1146
# Davis2006                   1514   7393     1544           1506        747
# Irvine2006                  1631   8255     1826           2086        720
# Los Angeles2006             1554   9527     1765           1529        621
# Merced2006                  1513   7393     1544           2013        743
# Riverside2006               1700   8000     2000           2000        726
# San Diego2006               1504   8501     1665           1925        738
# Santa Barbara2006           1505   9339     1766           1483        873
# Santa Cruz2006              1395   8712     1500           1563        945
# Systemwide2006              1502   8612     1689           1612        822
# Berkeley2007                1239   9343     1397           1380       1220
# Davis2007                   1508   7609     1404            977        801
# Irvine2007                  1564   8969     1855           2108        792
# Los Angeles2007             1515   9537     1749           1494        675
# Merced2007                  1474   7609     1404           2014        757
# Riverside2007               1692   8814     1947           2014        726
# San Diego2007               1487   9369     1601           2014        849
# Santa Barbara2007           1513   9415     1717           1487        918
# Santa Cruz2007              1325   9484     1541           1520       1044
# Systemwide2007              1463   9006     1611           1550        894
# Berkeley2008                1268   9528     1430           1002       1276
# Davis2008                   1544   7843     1437           1413        849
# Irvine2008                  1601   9245     1899           2158        729
# Los Angeles2008             1551   9834     1791           1530        756
# Merced2008                  1508   7843     1437           2062        841
# Riverside2008               1700   9100     1950           2050        675
# San Diego2008               1523   9624     1640           2062        849
# Santa Barbara2008           1549   9707     1794           1522        920
# Santa Cruz2008              1356   9675     1575           1557       1044
# Systemwide2008              1495   9256     1650           1584        914
# ...                          ...    ...      ...            ...        ...
# Berkeley2014                1229  10026     1758            725       2190
# Davis2014                   1560   8201     1928           1358       1854
# Irvine2014                  1732   9335     1960           1652       1398
# Los Angeles2014             1598  10138     1820           1093       1938
# Merced2014                  1419   6874     1828           1419       2016
# Riverside2014               1672   8577     1953           1640       1392
# San Diego2014               1509   9650     1927           1590       1632
# Santa Barbara2014           1391   9368     1876           1002       2569
# Santa Cruz2014              1438   9792     1756           1260       2414
# Systemwide2014              1511   9307     1866           1237       1951
# Berkeley2015                1241  10126     1775            732       2580
# Davis2015                   1576   8283     1947           1371       2115
# Irvine2015                  1749   9428     1980           1669       1497
# San Diego2016               12294        1351  30938
# Santa Barbara2016           12294        1778  31463
# Santa Cruz2016              12294        1244  31276
# Systemwide2016              12294        1299  30415
#
# [110 rows x 8 columns]

# %%
#basic matplotlib figure
data.plot(kind="bar")
plt.legend(bbox_to_anchor = (1.25, 1.00))
plt.show()
#fig = plt.gcf()
#py.iplot_mpl(fig)

# %%
area = bk.Area(df)
bk.show(area)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-3dd021dd4ed8> in <module>()
# ----> 1 area = bk.Area(df)
#       2 bk.show(area)
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\builders\area_builder.py in Area(data, x, y, **kws)
#      67     kws['x'] = x
#      68     kws['y'] = y
# ---> 69     return create_and_build(AreaBuilder, data, **kws)
#      70
#      71
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\builder.py in create_and_build(builder_class, *data, **kws)
#      65     chart_kws = { k:v for k,v in kws.items() if k not in builder_props}
#      66     chart = Chart(**chart_kws)
# ---> 67     chart.add_builder(builder)
#      68     chart.start_plot()
#      69
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\chart.py in add_builder(self, builder)
#     147     def add_builder(self, builder):
#     148         self._builders.append(builder)
# --> 149         builder.create(self)
#     150
#     151     def add_ranges(self, dim, range):
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\builder.py in create(self, chart)
#     516         if chart is None:
#     517             chart = Chart()
# --> 518         chart.add_renderers(self, renderers)
#     519
#     520         # handle ranges after renders, since ranges depend on aggregations
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\chart.py in add_renderers(self, builder, renderers)
#     142
#     143     def add_renderers(self, builder, renderers):
# --> 144         self.renderers += renderers
#     145         self._renderer_map.extend({ r._id : builder for r in renderers })
#     146
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\core\property_containers.py in wrapper(*args, **kwargs)
#      16         self = args[0]
#      17         old = self._saved_copy()
# ---> 18         result = func(*args, **kwargs)
#      19         self._notify_owners(old)
#      20         return result
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\core\property_containers.py in __iadd__(self, y)
#      75     @notify_owner
#      76     def __iadd__(self, y):
# ---> 77         return super(PropertyValueList, self).__iadd__(y)
#      78
#      79     # x *= y
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\builders\line_builder.py in yield_renderers(self)
#     242         if self.stack:
#     243             Stack().apply(self.comp_glyphs)
# --> 244         Dodge().apply(self.comp_glyphs)
#     245
#     246
#
# C:\Users\Megan\Desktop\Anaconda3\lib\site-packages\bokeh\charts\models.py in apply(self, renderers)
#     233         else:
#     234             raise AttributeError('%s must be applied to available renderers, none found.' %
# --> 235                                  self.__class__.__name__)
#
# AttributeError: Dodge must be applied to available renderers, none found.
